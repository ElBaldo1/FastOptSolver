# %% [markdown]
# # Test: ISTA vs FISTA on Synthetic LASSO Data
#
# This notebook compares ISTA and FISTA on a synthetic LASSO problem using objective and residual plots.

# %%
import numpy as np
from data.generate import generate_synthetic_lasso_data
from solvers.ista import ista
from solvers.fista import fista
from analysis.performance import evaluate_solver
from analysis.plotting import plot_history
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from data.generate import generate_synthetic_lasso_data
# ----> 3 from solvers.ista import ista
#       4 from solvers.fista import fista
#       5 from analysis.performance import evaluate_solver
#
# File ~/Desktop/ULB/continuos_optimization/progetto/pythonProject/solvers/ista.py:3
#       1 import numpy as np
#       2 from solvers.gradient import grad_f
# ----> 3 from prox.prox_l1 import prox_l1, lasso_objective
#       5 def ista(A, b, lam, step_size, max_iter=1000, tol=1e-6, verbose=False):
#       6     """
#       7     ISTA (Iterative Shrinkage-Thresholding Algorithm) for solving:
#       8         min_x 0.5 * ||Ax - b||^2 + lam * ||x||_1
#    (...)
#      35         - 'residual': list of ||x_k+1 - x_k|| per iteration
#      36     """
#
# ImportError: cannot import name 'lasso_objective' from 'prox.prox_l1' (/Users/antoniobaldari/Desktop/ULB/continuos_optimization/progetto/pythonProject/prox/prox_l1.py)

# %% [markdown]
# ## Generate synthetic dataset

# %%
A, b, x_true = generate_synthetic_lasso_data(m=100, n=200, sparsity=10, noise_std=0.01)
print("Data shape:", A.shape)

# %% [markdown]
# ## Set optimization parameters

# %%
lambda_ = 0.1
L = np.linalg.norm(A.T @ A, 2)
step_size = 1.0 / L
max_iter = 1000
tol = 1e-6

# %% [markdown]
# ## Run ISTA

# %%
x_ista, hist_ista = ista(A, b, lambda_, step_size, max_iter, tol, verbose=False)
results_ista = evaluate_solver(x_ista, x_true, hist_ista, name="ISTA")

# %% [markdown]
# ## Run FISTA

# %%
x_fista, hist_fista = fista(A, b, lambda_, step_size, max_iter, tol, verbose=False)
results_fista = evaluate_solver(x_fista, x_true, hist_fista, name="FISTA")

# %% [markdown]
# ## Plot objective and residuals

# %%
plot_history([results_ista, results_fista])
